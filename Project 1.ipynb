# %%
import pandas as pd
import csv
import json

# %%
heart = pd.read_csv("heart.csv") #read csv file
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart.to_json("heart.json") #convert csv file to json file

# %%
heart_data = pd.read_json("heart.json") #read json file

# %%
modified_heart = heart_data.drop(['target'], axis = 1) #remove last column of table
modified_heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal
# 0   2     3
# 1   0     3
# 2   0     3
# 3   1     3
# 4   3     2

# %%
columns = modified_heart.shape[0] 
records = modified_heart.shape[1] #rows
print("Data set contains", columns, "columns and", records, "records.")
# Out:
# Data set contains 1025 columns and 13 records.

# %%
# Finding the health status of a serum cholesterol (mg/dL) value as the input, should output the health status in addition to all data values in the data set that have the specified cholesterol value. 
def health_status(chol):
    if chol in modified_heart['chol'].unique():
        if chol < 125:
            data_sets = modified_heart.loc[modified_heart['chol'] == chol]
            print("Low cholesterol level") 
        if chol > 200:
            data_sets = modified_heart.loc[modified_heart['chol'] == chol]
            print("High cholesterol level")
        if 125 < chol < 200:
            data_sets = modified_heart.loc[modified_heart['chol'] == chol]
            print("Healthy cholesterol level")
        if type(chol) == None or type(chol) == string:
            print("Health status not available")
        return data_sets
    else:
        print("Health status not available")

# %%
health_status(61)
# Out:
# Low cholesterol level
# Health status not available
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]
# Index: []

# %%
# Using DataFrame.mean() method to get column average, this was for funsies sorry
chol_mean = modified_heart["chol"].mean()
print(chol_mean)
# Out:
# 246.0

# %%
health_status(212)
# Out:
# High cholesterol level
# Health status not available
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 58     67    1   2       152   212    0        0      150      0      0.8
# 63     59    1   2       150   212    1        1      157      0      1.6
# 195    59    1   2       150   212    1        1      157      0      1.6
# 241    67    1   2       152   212    0        0      150      0      0.8
# 293    59    1   2       150   212    1        1      157      0      1.6
# 430    67    1   2       152   212    0        0      150      0      0.8
# 594    64    1   0       145   212    0        0      132      0      2.0
# 606    66    1   0       112   212    0        0      132      1      0.1
# 608    64    1   0       145   212    0        0      132      0      2.0
# 634    52    1   0       125   212    0        1      168      0      1.0
# ...

# %%
health_status(187)
# Out:
# Healthy cholesterol level
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 77    63    1   0       140   187    0        0      144      1      4.0
# 92    63    1   0       140   187    0        0      144      1      4.0
# 180   63    1   0       140   187    0        0      144      1      4.0
# 764   63    1   0       140   187    0        0      144      1      4.0
#
#      slope  ca  thal
# 77       2   2     3
# 92       2   2     3
# 180      2   2     3
# 764      2   2     3

# %%
health_status(190)
# Out:
# Health status not available
